# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
train_path = "dataset/train"
val_path = "dataset/validation"

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    val_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       6 )
#       7
#       8 validation_datagen = ImageDataGenerator(rescale=1./255)
#       9
# ---> 10 train_generator = train_datagen.flow_from_directory(
#      11     train_path,
#      12     target_size=(128,128),
#      13     batch_size=32,
#
# File ~\Desktop\VIT\THIRD YEAR\FIRST SEM\DEEP_LEARNING\as6\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1137, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1119 def flow_from_directory(
#    1120     self,
#    1121     directory,
#    (...)   1135     keep_aspect_ratio=False,
#    1136 ):
# -> 1137     return DirectoryIterator(
#    1138         directory,
#    1139         self,
#    1140         target_size=target_size,
#    1141         color_mode=color_mode,
#    1142         keep_aspect_ratio=keep_aspect_ratio,
#    1143         classes=classes,
#    1144         class_mode=class_mode,
#    1145         data_format=self.data_format,
#    1146         batch_size=batch_size,
#    1147         shuffle=shuffle,
#    1148         seed=seed,
#    1149         save_to_dir=save_to_dir,
#    1150         save_prefix=save_prefix,
#    1151         save_format=save_format,
#    1152         follow_links=follow_links,
#    1153         subset=subset,
#    1154         interpolation=interpolation,
#    1155         dtype=self.dtype,
#    1156     )
#
# File ~\Desktop\VIT\THIRD YEAR\FIRST SEM\DEEP_LEARNING\as6\Lib\site-packages\keras\src\legacy\preprocessing\image.py:457, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     455 if not classes:
#     456     classes = []
# --> 457     for subdir in sorted(os.listdir(directory)):
#     458         if os.path.isdir(os.path.join(directory, subdir)):
#     459             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset/train'
